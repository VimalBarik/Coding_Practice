# %%
import pandas as pd

# %%
df = pd.read_excel('tickets_complex.xls')

# %%
pip install xlrd
# Out:
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df.sort_values('issue_type').head(15)
# Out:
#      ticket_id                                        ticket_text  \
# 553        554  Can't log in to my account. Keeps showing capt...
# 136        137  Can't log in to my account. Keeps showing capt...
# 793        794  Account problem. Assistance needed. Also, I co...
# 138        139  Can't log in to my account. Keeps showing rese...
# 584        585  Can't log in to my account. Keeps showing rese...
# 586        587  Can't log in to my account. Keeps showing capt...
# 281        282  Can't log in to my account. Keeps showing unkn...
# 142        143  Can't log in to my account. Keeps showing erro...
# 144        145                Account problem. Assistance needed.
# 795        796  Can't log in to my account. Keeps showing capt...
# 276        277  Can't log in to mi account. Keeps showing capt...
# 770        771                                                NaN
# 589        590                Account problem. Assistance needed.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ticket_id      1000 non-null   int64
#  1   ticket_text    945 non-null    object
#  2   issue_type     924 non-null    object
#  3   urgency_level  948 non-null    object
#  4   product        1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
df['product'].value_counts()
# Out:
# product
# RoboChef Blender     116
# Vision LED TV        109
# PhotoSnap Cam        103
# FitRun Treadmill     102
# PowerMax Battery     102
# EcoBreeze AC         100
# ProTab X1             99
# SmartWatch V2         95
# SoundWave 300         90
# UltraClean Vacuum     84
# Name: count, dtype: int64

# %%
df['issue_type'].value_counts()
# Out:
# issue_type
# Billing Problem       146
# General Inquiry       146
# Account Access        143
# Installation Issue    142
# Product Defect        121
# Wrong Item            114
# Late Delivery         112
# Name: count, dtype: int64

# %%
dfcsv = pd.read_csv('tickets_complex_cleaned.csv')

# %%
dfcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ticket_id      1000 non-null   int64
#  1   ticket_text    945 non-null    object
#  2   issue_type     997 non-null    object
#  3   urgency_level  1000 non-null   object
#  4   product        1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
dfcsv.sort_values('order_id')
# Out:
#      ticket_id                                        ticket_text  \
# 327        328         payment issue portal x charged twice 10170
# 446        447  ordered ultraclean vacuum got fibrin treadmill...
# 794        795  payment issue fr mi soundwave 300 refused fr 1...
# 629        630                  10394 3 day late ordered 05 march
# 310        311          payment issue soundwave 300 refused 10599
# ..         ...                                                ...
# 992        993                                                NaN
# 993        994                       received wrong product mixed
# 994        995                                         item stock
# 997        998                                                NaN
# 999       1000     powermax battery missing stopped working 1 day
#
#              issue_type urgency_level            product order_id
# 327     Billing Problem          High          Protab X1   #10170
# ...

# %%
dfcsv['order_id'].dropna().duplicated().value_counts()
# Out:
# order_id
# False    361
# Name: count, dtype: int64

# %%
print(duplicates)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: order_id, Length: 1000, dtype: bool

# %%
duplicates.value_counts()
# Out:
# order_id
# True     638
# False    362
# Name: count, dtype: int64

# %%
duplicates.unique()
# Out:
# array([False,  True])
