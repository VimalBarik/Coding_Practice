# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.448313 -1.339719 -0.571183  2.039078
# 2013-01-03 -1.328443 -0.016401  1.286920 -0.699055
# 2013-01-04  1.124484 -0.589912 -2.847483  1.567676

# %%
df.loc[dates[0]]
# Out:
# A   -0.934580
# B    0.590852
# C   -0.521059
# D    0.579629
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -0.934580  0.590852
# 2013-01-02 -0.448313 -1.339719
# 2013-01-03 -1.328443 -0.016401
# 2013-01-04  1.124484 -0.589912
# 2013-01-05 -0.957137  0.550070
# 2013-01-06 -0.221867 -1.565888

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.448313 -1.339719
# 2013-01-03 -1.328443 -0.016401
# 2013-01-04  1.124484 -0.589912

# %%
df.loc[dates[0], "A"]
# Out:
# -0.9345804214786414

# %%
df.at[dates[0], "A"]
# Out:
# -0.9345804214786414

# %%
df.iloc[3]
# Out:
# A    1.124484
# B   -0.589912
# C   -2.847483
# D    1.567676
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  1.124484 -0.589912
# 2013-01-05 -0.957137  0.550070

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -0.448313 -0.571183
# 2013-01-03 -1.328443  1.286920
# 2013-01-05 -0.957137 -0.461738

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.448313 -1.339719 -0.571183  2.039078
# 2013-01-03 -1.328443 -0.016401  1.286920 -0.699055

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.590852 -0.521059
# 2013-01-02 -1.339719 -0.571183
# 2013-01-03 -0.016401  1.286920
# 2013-01-04 -0.589912 -2.847483
# 2013-01-05  0.550070 -0.461738
# 2013-01-06 -1.565888  1.461616

# %%
df.iloc[1, 1]
# Out:
# -1.3397187398445596

# %%
df.iat[1, 1]
# Out:
# -1.3397187398445596

# %%
df[df["A"] >  0]
# Out:
#                    A         B         C         D
# 2013-01-04  1.124484 -0.589912 -2.847483  1.567676

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.590852       NaN  0.579629
# 2013-01-02       NaN       NaN       NaN  2.039078
# 2013-01-03       NaN       NaN  1.286920       NaN
# 2013-01-04  1.124484       NaN       NaN  1.567676
# 2013-01-05       NaN  0.550070       NaN  0.794312
# 2013-01-06       NaN       NaN  1.461616  0.452483

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.934580  0.590852 -0.521059  0.579629    one
# 2013-01-02 -0.448313 -1.339719 -0.571183  2.039078    one
# 2013-01-03 -1.328443 -0.016401  1.286920 -0.699055    two
# 2013-01-04  1.124484 -0.589912 -2.847483  1.567676  three
# 2013-01-05 -0.957137  0.550070 -0.461738  0.794312   four
# 2013-01-06 -0.221867 -1.565888  1.461616  0.452483  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.328443 -0.016401  1.286920 -0.699055   two
# 2013-01-05 -0.957137  0.550070 -0.461738  0.794312  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.521059  5.0  NaN
# 2013-01-02 -0.448313 -1.339719 -0.571183  5.0  1.0
# 2013-01-03 -1.328443 -0.016401  1.286920  5.0  2.0
# 2013-01-04  1.124484 -0.589912 -2.847483  5.0  3.0
# 2013-01-05 -0.957137  0.550070 -0.461738  5.0  4.0
# 2013-01-06 -0.221867 -1.565888  1.461616  5.0  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.521059 -5.0  NaN
# 2013-01-02 -0.448313 -1.339719 -0.571183 -5.0 -1.0
# 2013-01-03 -1.328443 -0.016401 -1.286920 -5.0 -2.0
# 2013-01-04 -1.124484 -0.589912 -2.847483 -5.0 -3.0
# 2013-01-05 -0.957137 -0.550070 -0.461738 -5.0 -4.0
# 2013-01-06 -0.221867 -1.565888 -1.461616 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.521059  5.0  NaN  1.0
# 2013-01-02 -0.448313 -1.339719 -0.571183  5.0  1.0  1.0
# 2013-01-03 -1.328443 -0.016401  1.286920  5.0  2.0  NaN
# 2013-01-04  1.124484 -0.589912 -2.847483  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02 -0.448313 -1.339719 -0.571183  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.521059  5.0  5.0  1.0
# 2013-01-02 -0.448313 -1.339719 -0.571183  5.0  1.0  1.0
# 2013-01-03 -1.328443 -0.016401  1.286920  5.0  2.0  5.0
# 2013-01-04  1.124484 -0.589912 -2.847483  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.305213
# B   -0.493642
# C   -0.275488
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.119735
# 2013-01-02    0.728157
# 2013-01-03    1.388415
# 2013-01-04    1.137418
# 2013-01-05    1.626239
# 2013-01-06    1.934772
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -2.328443 -1.016401  0.286920  4.0  1.0
# 2013-01-04 -1.875516 -3.589912 -5.847483  2.0  0.0
# 2013-01-05 -5.957137 -4.449930 -5.461738  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -1.709191
# B    -2.764393
# C    -1.542732
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000  -52.731192  506.0    NaN
# 2013-01-02  -45.369258 -135.579536  -57.803752  506.0  101.2
# 2013-01-03 -134.438443   -1.659791  130.236287  506.0  202.4
# 2013-01-04  113.797793  -59.699072 -288.165231  506.0  303.6
# 2013-01-05  -96.862236   55.667122  -46.727887  506.0  404.8
# 2013-01-06  -22.452957 -158.467864  147.915588  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    4
# 4    0
# 5    2
# 6    0
# 7    1
# 8    4
# 9    5
# dtype: int64

# %%
s.value_counts()
# Out:
# 1    2
# 5    2
# 4    2
# 0    2
# 3    1
# 2    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2    aaba
# 3    baca
# 4     NaN
# 5    caba
# 6     dog
# 7     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  1.054559 -1.496947 -0.864913 -0.802105
# 1  0.037033  0.995661 -1.432674 -1.539096
# 2 -2.646667  0.382824 -0.515442  0.353241
# 3  0.422822  0.059302  0.990922  0.164418
# 4  0.636212 -0.222983  0.042416 -0.639749
# 5 -0.668280  1.147377 -0.638392  0.218315
# 6  0.665670  0.587249  1.482650 -0.050416
# 7  2.555123  0.269252 -0.939187  0.151796
# 8 -0.237834  0.266415  1.081596  0.175571
# 9  0.197618 -0.885216 -0.588320  0.143699

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.054559 -1.496947 -0.864913 -0.802105
# 1  0.037033  0.995661 -1.432674 -1.539096
# 2 -2.646667  0.382824 -0.515442  0.353241
# 3  0.422822  0.059302  0.990922  0.164418
# 4  0.636212 -0.222983  0.042416 -0.639749
# 5 -0.668280  1.147377 -0.638392  0.218315
# 6  0.665670  0.587249  1.482650 -0.050416
# 7  2.555123  0.269252 -0.939187  0.151796
# 8 -0.237834  0.266415  1.081596  0.175571
# 9  0.197618 -0.885216 -0.588320  0.143699

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  2.987338  0.565646
# 1  bar    one  0.233256  0.315680
# 2  foo    two -1.307917  0.478150
# 3  bar  three  0.730553  0.470827
# 4  foo    two -0.320090  0.583256
# 5  bar    two  1.204583  0.093438
# 6  foo    one  0.415041 -0.609644
# 7  foo  three -0.589376 -0.467423

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  2.168392  0.879946
# foo  1.184995  0.549985

# %%
arrays = [
    ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
    ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.785902  1.828797
#       two    -0.590360 -0.309325
# baz   one     0.419874 -1.457843
#       two     0.215136  0.382746

# %%
stacked = df2.stack(future_stack=True)

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.785902
#                B    1.828797
#        two     A   -0.590360
#                B   -0.309325
# baz    one     A    0.419874
#                B   -1.457843
#        two     A    0.215136
#                B    0.382746
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.785902  1.828797
#       two    -0.590360 -0.309325
# baz   one     0.419874 -1.457843
#       two     0.215136  0.382746

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.785902 -0.590360
#       B  1.828797 -0.309325
# baz   A  0.419874  0.215136
#       B -1.457843  0.382746

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.785902  0.419874
#        B  1.828797 -1.457843
# two    A -0.590360  0.215136
#        B -0.309325  0.382746

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.553394 -1.946865
# 1     one  B  foo  2.100647  0.223351
# 2     two  C  foo  0.361101 -0.348832
# 3   three  A  bar  1.118986 -0.955641
# 4     one  B  bar -0.283449  2.400776
# 5     one  C  bar -1.083485 -0.589585
# 6     two  A  foo  1.487353 -0.760732
# 7   three  B  foo  0.741687  0.622085
# 8     one  C  foo -1.224395 -0.711240
# 9     one  A  bar  0.564601  2.069838
# 10    two  B  bar -0.511628  0.552838
# 11  three  C  bar -1.990092 -1.195798

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.564601 -1.553394
#       B -0.283449  2.100647
#       C -1.083485 -1.224395
# three A  1.118986       NaN
#       B       NaN  0.741687
#       C -1.990092       NaN
# two   A       NaN  1.487353
#       B -0.511628       NaN
#       C       NaN  0.361101

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    25857
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.245062
# 2012-03-07    1.007680
# 2012-03-08    1.011964
# 2012-03-09   -0.859933
# 2012-03-10    1.184461
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.245062
# 2012-03-07 00:00:00+00:00    1.007680
# 2012-03-08 00:00:00+00:00    1.011964
# 2012-03-09 00:00:00+00:00   -0.859933
# 2012-03-10 00:00:00+00:00    1.184461
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.245062
# 2012-03-06 19:00:00-05:00    1.007680
# 2012-03-07 19:00:00-05:00    1.011964
# 2012-03-08 19:00:00-05:00   -0.859933
# 2012-03-09 19:00:00-05:00    1.184461
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)
