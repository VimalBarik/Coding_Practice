# %%
import numpy as np

# %%
import pandas as pd

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.067314 -1.310188 -1.023835 -0.456309
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170
# 2013-01-04  0.454959 -0.258773 -0.673581 -1.317247
# 2013-01-05 -1.644708  0.456374  1.426914 -0.601495
# 2013-01-06 -0.577692  0.917227 -1.966484 -0.379173

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.067314 -1.310188 -1.023835 -0.456309
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170
# 2013-01-04  0.454959 -0.258773 -0.673581 -1.317247
# 2013-01-05 -1.644708  0.456374  1.426914 -0.601495

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.454959 -0.258773 -0.673581 -1.317247
# 2013-01-05 -1.644708  0.456374  1.426914 -0.601495
# 2013-01-06 -0.577692  0.917227 -1.966484 -0.379173

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.06731358, -1.31018785, -1.02383503, -0.45630931],
#        [ 0.07949776, -2.26495827,  0.45164575, -0.40410726],
#        [-2.06098097, -0.18857179, -0.09651173,  0.83617043],
#        [ 0.45495894, -0.25877266, -0.67358076, -1.31724672],
#        [-1.64470766,  0.4563742 ,  1.42691437, -0.60149461],
#        [-0.5776925 ,  0.91722719, -1.96648409, -0.37917339]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.613602 -0.441482 -0.313642 -0.387027
# std    1.024229  1.168700  1.185594  0.694647
# min   -2.060981 -2.264958 -1.966484 -1.317247
# 25%   -1.377954 -1.047334 -0.936271 -0.565198
# 50%   -0.255189 -0.223672 -0.385046 -0.430208
# 75%    0.076452  0.295138  0.314606 -0.385407
# max    0.454959  0.917227  1.426914  0.836170

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.067314    0.079498   -2.060981    0.454959   -1.644708   -0.577692
# B   -1.310188   -2.264958   -0.188572   -0.258773    0.456374    0.917227
# C   -1.023835    0.451646   -0.096512   -0.673581    1.426914   -1.966484
# D   -0.456309   -0.404107    0.836170   -1.317247   -0.601495   -0.379173

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.456309 -1.023835 -1.310188  0.067314
# 2013-01-02 -0.404107  0.451646 -2.264958  0.079498
# 2013-01-03  0.836170 -0.096512 -0.188572 -2.060981
# 2013-01-04 -1.317247 -0.673581 -0.258773  0.454959
# 2013-01-05 -0.601495  1.426914  0.456374 -1.644708
# 2013-01-06 -0.379173 -1.966484  0.917227 -0.577692

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107
# 2013-01-01  0.067314 -1.310188 -1.023835 -0.456309
# 2013-01-04  0.454959 -0.258773 -0.673581 -1.317247
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170
# 2013-01-05 -1.644708  0.456374  1.426914 -0.601495
# 2013-01-06 -0.577692  0.917227 -1.966484 -0.379173

# %%
df["A"]
# Out:
# 2013-01-01    0.067314
# 2013-01-02    0.079498
# 2013-01-03   -2.060981
# 2013-01-04    0.454959
# 2013-01-05   -1.644708
# 2013-01-06   -0.577692
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.067314 -1.310188 -1.023835 -0.456309
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170
# 2013-01-04  0.454959 -0.258773 -0.673581 -1.317247

# %%
df.loc[dates[0]]
# Out:
# A    0.067314
# B   -1.310188
# C   -1.023835
# D   -0.456309
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.067314 -1.310188
# 2013-01-02  0.079498 -2.264958
# 2013-01-03 -2.060981 -0.188572
# 2013-01-04  0.454959 -0.258773
# 2013-01-05 -1.644708  0.456374
# 2013-01-06 -0.577692  0.917227

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  0.079498 -2.264958
# 2013-01-03 -2.060981 -0.188572
# 2013-01-04  0.454959 -0.258773

# %%
df.loc[dates[0], "A"]
# Out:
# 0.06731358485383489

# %%
df.at[dates[0], "A"]
# Out:
# 0.06731358485383489

# %%
df.iloc[3]
# Out:
# A    0.454959
# B   -0.258773
# C   -0.673581
# D   -1.317247
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.454959 -0.258773
# 2013-01-05 -1.644708  0.456374

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02  0.079498  0.451646
# 2013-01-03 -2.060981 -0.096512
# 2013-01-05 -1.644708  1.426914

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -1.310188 -1.023835
# 2013-01-02 -2.264958  0.451646
# 2013-01-03 -0.188572 -0.096512
# 2013-01-04 -0.258773 -0.673581
# 2013-01-05  0.456374  1.426914
# 2013-01-06  0.917227 -1.966484

# %%
df.iloc[1,1]
# Out:
# -2.264958274570913

# %%
df.iat[1,1]
# Out:
# -2.264958274570913

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.067314 -1.310188 -1.023835 -0.456309
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107
# 2013-01-04  0.454959 -0.258773 -0.673581 -1.317247

# %%
df[df > 0]
# Out:
#                    A         B         C        D
# 2013-01-01  0.067314       NaN       NaN      NaN
# 2013-01-02  0.079498       NaN  0.451646      NaN
# 2013-01-03       NaN       NaN       NaN  0.83617
# 2013-01-04  0.454959       NaN       NaN      NaN
# 2013-01-05       NaN  0.456374  1.426914      NaN
# 2013-01-06       NaN  0.917227       NaN      NaN

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.067314 -1.310188 -1.023835 -0.456309    one
# 2013-01-02  0.079498 -2.264958  0.451646 -0.404107    one
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170    two
# 2013-01-04  0.454959 -0.258773 -0.673581 -1.317247  three
# 2013-01-05 -1.644708  0.456374  1.426914 -0.601495   four
# 2013-01-06 -0.577692  0.917227 -1.966484 -0.379173  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -2.060981 -0.188572 -0.096512  0.836170   two
# 2013-01-05 -1.644708  0.456374  1.426914 -0.601495  four

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0,1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -1.023835  5.0  NaN
# 2013-01-02  0.079498 -2.264958  0.451646  5.0  1.0
# 2013-01-03 -2.060981 -0.188572 -0.096512  5.0  2.0
# 2013-01-04  0.454959 -0.258773 -0.673581  5.0  3.0
# 2013-01-05 -1.644708  0.456374  1.426914  5.0  4.0
# 2013-01-06 -0.577692  0.917227 -1.966484  5.0  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -1.023835 -5.0  NaN
# 2013-01-02 -0.079498 -2.264958 -0.451646 -5.0 -1.0
# 2013-01-03 -2.060981 -0.188572 -0.096512 -5.0 -2.0
# 2013-01-04 -0.454959 -0.258773 -0.673581 -5.0 -3.0
# 2013-01-05 -1.644708 -0.456374 -1.426914 -5.0 -4.0
# 2013-01-06 -0.577692 -0.917227 -1.966484 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -1.023835  5.0  NaN  1.0
# 2013-01-02  0.079498 -2.264958  0.451646  5.0  1.0  1.0
# 2013-01-03 -2.060981 -0.188572 -0.096512  5.0  2.0  NaN
# 2013-01-04  0.454959 -0.258773 -0.673581  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02  0.079498 -2.264958  0.451646  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -1.023835  5.0  5.0  1.0
# 2013-01-02  0.079498 -2.264958  0.451646  5.0  1.0  1.0
# 2013-01-03 -2.060981 -0.188572 -0.096512  5.0  2.0  5.0
# 2013-01-04  0.454959 -0.258773 -0.673581  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.624821
# B   -0.223117
# C   -0.313642
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.994041
# 2013-01-02    0.853237
# 2013-01-03    0.930787
# 2013-01-04    1.504521
# 2013-01-05    1.847716
# 2013-01-06    1.674610
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -3.060981 -1.188572 -1.096512  4.0  1.0
# 2013-01-04 -2.545041 -3.258773 -3.673581  2.0  0.0
# 2013-01-05 -6.644708 -4.543626 -3.573086  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -3.498996
# B    -1.249455
# C    -1.756395
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000 -103.612105  506.0    NaN
# 2013-01-02    8.045174 -229.213777   45.706550  506.0  101.2
# 2013-01-03 -208.571274  -19.083465   -9.766987  506.0  202.4
# 2013-01-04   46.041845  -26.187793  -68.166373  506.0  303.6
# 2013-01-05 -166.444415   46.185069  144.403734  506.0  404.8
# 2013-01-06  -58.462481   92.823392 -199.008189  506.0  506.0

# %%
s = pd.Series(np.random.randint(0,7,size=10))

# %%
s
# Out:
# 0    2
# 1    5
# 2    4
# 3    0
# 4    6
# 5    4
# 6    2
# 7    0
# 8    3
# 9    2
# dtype: int64

# %%
s.value_counts()
# Out:
# 2    3
# 4    2
# 0    2
# 5    1
# 6    1
# 3    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0 -0.050254  0.068675 -0.070664  1.031186
# 1 -0.895695 -0.127840 -0.621010 -0.226012
# 2  0.927091 -1.602429 -0.653324  0.247111
# 3  0.388913 -0.044643  1.242793  1.092685
# 4 -0.476505 -1.454256 -1.200248  0.021559
# 5  0.129234  0.324200 -0.821338  1.383276
# 6  1.106867  1.887715  1.295733 -0.509936
# 7 -0.067193  0.245930 -0.616422  1.481982
# 8  0.272707 -0.966223  0.982298 -0.101942
# 9  0.320710  0.728910  0.339326 -0.092767

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.050254  0.068675 -0.070664  1.031186
# 1 -0.895695 -0.127840 -0.621010 -0.226012
# 2  0.927091 -1.602429 -0.653324  0.247111
# 3  0.388913 -0.044643  1.242793  1.092685
# 4 -0.476505 -1.454256 -1.200248  0.021559
# 5  0.129234  0.324200 -0.821338  1.383276
# 6  1.106867  1.887715  1.295733 -0.509936
# 7 -0.067193  0.245930 -0.616422  1.481982
# 8  0.272707 -0.966223  0.982298 -0.101942
# 9  0.320710  0.728910  0.339326 -0.092767

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval":[1,2]})

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1,2]})

# %%
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -1.214309  0.675526
# 1  bar    one -0.552667  0.770114
# 2  foo    two  0.355715  0.614373
# 3  bar  three -0.937913 -0.923874
# 4  foo    two -2.137192  0.563810
# 5  bar    two -0.272541 -0.345354
# 6  foo    one  0.177565 -0.057097
# 7  foo  three  0.990549  1.388442

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -1.763121 -0.499114
# foo -1.827671  3.185054

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.552667  0.770114
#     three -0.937913 -0.923874
#     two   -0.272541 -0.345354
# foo one   -1.036744  0.618429
#     three  0.990549  1.388442
#     two   -1.781477  1.178183

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8,2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.109609  0.761626
#       two    -1.286349  0.878116
# baz   one     0.230370 -1.045035
#       two     1.040892  0.382018

# %%
stacked = df2.stack(future_stack=True)

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.109609
#                B    0.761626
#        two     A   -1.286349
#                B    0.878116
# baz    one     A    0.230370
#                B   -1.045035
#        two     A    1.040892
#                B    0.382018
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.109609  0.761626
#       two    -1.286349  0.878116
# baz   one     0.230370 -1.045035
#       two     1.040892  0.382018

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.109609 -1.286349
#       B  0.761626  0.878116
# baz   A  0.230370  1.040892
#       B -1.045035  0.382018

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.109609  0.230370
#        B  0.761626 -1.045035
# two    A -1.286349  1.040892
#        B  0.878116  0.382018

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.761505 -1.106012
# 1     one  B  foo  0.036709 -0.729838
# 2     two  C  foo  1.522038  0.782628
# 3   three  A  bar -0.259635 -0.063420
# 4     one  B  bar -0.805956  0.398096
# 5     one  C  bar  0.694087 -2.059436
# 6     two  A  foo  0.834586 -0.488368
# 7   three  B  foo  1.990702  2.069653
# 8     one  C  foo -1.875890 -0.420558
# 9     one  A  bar -0.019042 -0.155010
# 10    two  B  bar  0.751878 -0.831665
# 11  three  C  bar -0.638376  1.318524

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.019042 -1.761505
#       B -0.805956  0.036709
#       C  0.694087 -1.875890
# three A -0.259635       NaN
#       B       NaN  1.990702
#       C -0.638376       NaN
# two   A       NaN  0.834586
#       B  0.751878       NaN
#       C       NaN  1.522038

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

# %%
ts = pd.Series(np.random.randint(0,500,len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    22793
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.988850
# 2012-03-07    0.138415
# 2012-03-08   -0.421382
# 2012-03-09    0.622476
# 2012-03-10    0.115075
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.988850
# 2012-03-07 00:00:00+00:00    0.138415
# 2012-03-08 00:00:00+00:00   -0.421382
# 2012-03-09 00:00:00+00:00    0.622476
# 2012-03-10 00:00:00+00:00    0.115075
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.988850
# 2012-03-06 19:00:00-05:00    0.138415
# 2012-03-07 19:00:00-05:00   -0.421382
# 2012-03-08 19:00:00-05:00    0.622476
# 2012-03-09 19:00:00-05:00    0.115075
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1,2,3,4,5,6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df = df.cumsum()

# %%
plt.figure();

# %%
df.plot();

# %%
plt.legend(loc="best");
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df = pd.DataFrame(np.random.randint(0,5,(10,5)))

# %%
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  4  0  4  3
# 1           1  3  0  3  4  0
# 2           2  4  3  3  1  0
# 3           3  3  4  2  2  2
# 4           4  2  0  2  2  0
# 5           5  0  3  2  4  4
# 6           6  3  2  3  2  4
# 7           7  2  4  4  4  4
# 8           8  2  0  3  2  4
# 9           9  0  0  3  1  1

# %%
df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  0  4  0  4  3
# 1  3  0  3  4  0
# 2  4  3  3  1  0
# 3  3  4  2  2  2
# 4  2  0  2  2  0
# 5  0  3  2  4  4
# 6  3  2  3  2  4
# 7  2  4  4  4  4
# 8  2  0  3  2  4
# 9  0  0  3  1  1

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  4  0  4  3
# 1           1  3  0  3  4  0
# 2           2  4  3  3  1  0
# 3           3  3  4  2  2  2
# 4           4  2  0  2  2  0
# 5           5  0  3  2  4  4
# 6           6  3  2  3  2  4
# 7           7  2  4  4  4  4
# 8           8  2  0  3  2  4
# 9           9  0  0  3  1  1

# %%
if pd.Series([False, True, False]):
    print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/5v/vrjpghjd6l108t51_2jw8tzr0000gn/T/ipykernel_3798/2648304181.py in ?()
# ----> 1 if pd.Series([False, True, False]):
#       2     print("I was true")
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
