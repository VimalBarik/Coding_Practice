# %%
import pandas as pd
state = pd.read_csv("state.csv")

# %%
state["Population"].mean()
# Out:
# np.float64(7694135.625)

# %%
from scipy.stats import trim_mean

# %%
trim_mean(state["Population"], 0.1)
# Out:
# np.float64(7694135.625)

# %%
state['Population'].median()
# Out:
# np.float64(4176916.5)

# %%
import numpy as np

# %%
np.average(state["Murder_rate"], weights=state["Population"])
# Out:
# np.float64(4.376359279149048)

# %%
print(state.columns)
# Out:
# Index(['State', 'Population', 'Murder_rate', 'Abbreviation'], dtype='object')

# %%
pip install wquantiles
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.5_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import wquantiles

# %%
wquantiles.median(state['Murder_rate'], weights=state['Population'])
# Out:
# np.float64(4.448750497554494)

# %%
state["Population"].std()
# Out:
# np.float64(12105745.29585633)

# %%
state["Population"].quantile(0.75) - state["Population"].quantile(0.25)
# Out:
# np.float64(2958479.25)

# %%
pip install statsmodels
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.5_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.robust.scale import mad

# %%
mad(state["Population"])
# Out:
# np.float64(2576836.044572552)

# %%
state["Murder_rate"].quantile([0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
# 0.05    2.540
# 0.25    4.000
# 0.50    5.150
# 0.75    5.625
# 0.95    5.765
# Name: Murder_rate, dtype: float64

# %%
ax = (state["Population"]/1000000).plot.box()
ax.set_ylabel("Population (millions)")
# Out:
# Text(0, 0.5, 'Population (millions)')

# %%
binnedPopulation = pd.cut(state["Population"], 30)
binnedPopulation.value_counts()
# Out:
# Population
# (673687.275, 1928355.167]       2
# (4364603.5, 5582727.667]        2
# (5582727.667, 6800851.833]      1
# (1928355.167, 3146479.333]      1
# (36035831.833, 37253956.0]      1
# (3146479.333, 4364603.5]        1
# (6800851.833, 8018976.0]        0
# (22636466.0, 23854590.167]      0
# (34817707.667, 36035831.833]    0
# (33599583.5, 34817707.667]      0
# (32381459.333, 33599583.5]      0
# (31163335.167, 32381459.333]    0
# (29945211.0, 31163335.167]      0
# (28727086.833, 29945211.0]      0
# (27508962.667, 28727086.833]    0
# (26290838.5, 27508962.667]      0
# (25072714.333, 26290838.5]      0
# (23854590.167, 25072714.333]    0
# (21418341.833, 22636466.0]      0
# (8018976.0, 9237100.167]        0
# (20200217.667, 21418341.833]    0
# (17763969.333, 18982093.5]      0
# (16545845.167, 17763969.333]    0
# (15327721.0, 16545845.167]      0
# (14109596.833, 15327721.0]      0
# (12891472.667, 14109596.833]    0
# (11673348.5, 12891472.667]      0
# ...

# %%
ax = (state["Population"]/1000000).plot.hist(figsize=(4,4))
ax.set_xlabel("Population (million)")
# Out:
# Text(0.5, 0, 'Population (million)')

# %%
ax = state["Murder_rate"].plot.hist(density=True, xlim=[0,12], bins=range(1, 12))
state["Murder_rate"].plot.density(ax=ax)
ax.set_xlabel("Muder rate (per 100,000)")
# Out:
# Text(0.5, 0, 'Muder rate (per 100,000)')
