# %%
pip install tensorflow-metal
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-metal (from versions: none)
# ERROR: No matching distribution found for tensorflow-metal
# Note: you may need to restart the kernel to use updated packages.
# ⏱️  Cell executed in 0.83 s

# %%
import tensorflow as tf
print("TF version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))

# %%
pip uninstall protobuf -y
# Out:
# Found existing installation: protobuf 6.31.1
# Uninstalling protobuf-6.31.1:
#   Successfully uninstalled protobuf-6.31.1
# Note: you may need to restart the kernel to use updated packages.
# ⏱️  Cell executed in 0.52 s

# %%
pip install "protobuf>=5.28,<6"
# Out:
# Collecting protobuf<6,>=5.28
#   Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl (418 kB)
# Installing collected packages: protobuf
# Successfully installed protobuf-5.29.5
# Note: you may need to restart the kernel to use updated packages.
# ⏱️  Cell executed in 1.10 s

# %%
import google.protobuf
print(google.protobuf.__version__)
# Out:
# 5.29.5
# ⏱️  Cell executed in 0.00 s

# %%
import tensorflow as tf
print(tf.__version__)

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined
# ⏱️  Cell executed in 0.12 s
